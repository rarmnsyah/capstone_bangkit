# %%
# !docker pull tensorflow/serving
# Out:
# Using default tag: latest
# latest: Pulling from tensorflow/serving
# Digest: sha256:fdc296e313fa4454173c5728fceda38f5d18cdb44c71a9f279ce61bc5818335e
# Status: Image is up to date for tensorflow/serving:latest
# docker.io/tensorflow/serving:latest
# What's Next?
#   View a summary of image vulnerabilities and recommendations → docker scout quickview tensorflow/serving

# %%
# !git clone https://github.com/tensorflow/serving
# Out:
# Cloning into 'serving'...
# Updating files:  73% (471/643)
# Updating files:  74% (476/643)
# Updating files:  75% (483/643)
# Updating files:  76% (489/643)
# Updating files:  77% (496/643)
# Updating files:  78% (502/643)
# Updating files:  79% (508/643)
# Updating files:  80% (515/643)
# Updating files:  81% (521/643)
# Updating files:  82% (528/643)
# Updating files:  83% (534/643)
# Updating files:  84% (541/643)
# Updating files:  85% (547/643)
# Updating files:  86% (553/643)
# Updating files:  87% (560/643)
# Updating files:  88% (566/643)
# Updating files:  89% (573/643)
# Updating files:  90% (579/643)
# Updating files:  91% (586/643)
# Updating files:  92% (592/643)
# Updating files:  93% (598/643)
# Updating files:  94% (605/643)
# Updating files:  95% (611/643)
# Updating files:  96% (618/643)
# Updating files:  97% (624/643)
# Updating files:  98% (631/643)
# Updating files:  99% (637/643)
# Updating files: 100% (643/643)
# Updating files: 100% (643/643), done.

# %%
# !Powershell.exe -Command "Set-Variable -Name "TESTDATA" -Value "$(pwd)/serving/tensorflow_serving/servables/tensorflow/testdata""
# Out:
# Set-Variable : A positional parameter cannot be found that accepts argument
# '/serving/tensorflow_serving/servables/tensorflow/testdata'.
# At line:1 char:1
# + Set-Variable -Name TESTDATA -Value $(pwd)/serving/tensorflow_serving/ ...
# + ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : InvalidArgument: (:) [Set-Variable], ParameterBindingException
#     + FullyQualifiedErrorId : PositionalParameterNotFound,Microsoft.PowerShell.Commands.SetVariabl
#    eCommand

# %%
# !Powershell.exe -Command "docker run -t --rm -p 8501:8501 -v "$TESTDATA/saved_model_half_plus_two_cpu:/models/half_plus_two" -e MODEL_NAME=half_plus_two tensorflow/serving"
# Out:
# ^C
# 2023-12-09 17:30:59.384587: I tensorflow_serving/model_servers/server.cc:74] Building single TensorFlow model file config:  model_name: half_plus_two model_base_path: /models/half_plus_two
# 2023-12-09 17:30:59.386495: I tensorflow_serving/model_servers/server_core.cc:467] Adding/updating models.
# 2023-12-09 17:30:59.386628: I tensorflow_serving/model_servers/server_core.cc:596]  (Re-)adding model: half_plus_two
# 2023-12-09 17:30:59.388457: W tensorflow_serving/sources/storage_path/file_system_storage_path_source.cc:252] No versions of servable half_plus_two found under base path /models/half_plus_two. Did you forget to name your leaf directory as a number (eg. '/1/')?
# 2023-12-09 17:31:00.388515: W tensorflow_serving/sources/storage_path/file_system_storage_path_source.cc:252] No versions of servable half_plus_two found under base path /models/half_plus_two. Did you forget to name your leaf directory as a number (eg. '/1/')?
# ...
